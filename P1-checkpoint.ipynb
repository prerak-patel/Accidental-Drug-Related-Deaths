# %%
#What are the drugs of choice for this location?

import pandas as pd 
import matplotlib.pyplot as plt 
import scipy.stats as st 
import numpy as np 
import random 

#data file 
accidental_drug_related = "Accidental_Drug_Related_Deaths_2012-2018.csv"

#read csv data and analyze results 
accidental_drug_related = pd.read_csv(accidental_drug_related)
accidental_drug_related.head()
# Out:
#         ID                    Date      DateType   Age     Sex          Race  \
# 0  14-0273  06/28/2014 12:00:00 AM  DateReported   NaN     NaN           NaN
# 1  13-0102  03/21/2013 12:00:00 AM   DateofDeath  48.0    Male         Black
# 2  16-0165  03/13/2016 12:00:00 AM   DateofDeath  30.0  Female         White
# 3  16-0208  03/31/2016 12:00:00 AM   DateofDeath  23.0    Male         White
# 4  13-0052  02/13/2013 12:00:00 AM   DateofDeath  22.0    Male  Asian, Other
#
#   ResidenceCity ResidenceCounty ResidenceState  DeathCity  ... Tramad  \
# 0           NaN             NaN            NaN        NaN  ...    NaN
# 1       NORWALK             NaN            NaN    NORWALK  ...    NaN
# 2    SANDY HOOK       FAIRFIELD             CT    DANBURY  ...    NaN
# 3           RYE     WESTCHESTER             NY  GREENWICH  ...    NaN
# 4      FLUSHING          QUEENS            NaN  GREENWICH  ...    NaN
#
#   Morphine_NotHeroin Hydromorphone Other OpiateNOS AnyOpioid MannerofDeath  \
# ...

# %%
accidental_drug_related.drop(['ID','Date','DateType','Age','Sex','Race','MannerofDeath',
'DeathCityGeo','ResidenceCityGeo','InjuryCityGeo','DescriptionofInjury','InjuryPlace','InjuryCity',
'InjuryCounty','InjuryState','COD','OtherSignifican','OpiateNOS','AnyOpioid','MannerofDeath',
'DeathCityGeo','ResidenceCityGeo','InjuryCityGeo','Location','LocationifOther'], axis=1, inplace=True)

# %%
accidental_drug_related.head()
# Out:
#   ResidenceCity ResidenceCounty ResidenceState  DeathCity DeathCounty Heroin  \
# 0           NaN             NaN            NaN        NaN         NaN    NaN
# 1       NORWALK             NaN            NaN    NORWALK   FAIRFIELD    NaN
# 2    SANDY HOOK       FAIRFIELD             CT    DANBURY         NaN      Y
# 3           RYE     WESTCHESTER             NY  GREENWICH         NaN      Y
# 4      FLUSHING          QUEENS            NaN  GREENWICH   FAIRFIELD    NaN
#
#   Cocaine Fentanyl FentanylAnalogue Oxycodone Oxymorphone Ethanol Hydrocodone  \
# 0     NaN        Y              NaN       NaN         NaN     NaN           Y
# 1       Y      NaN              NaN       NaN         NaN     NaN         NaN
# 2       Y      NaN              NaN       NaN         NaN     NaN         NaN
# 3     NaN        Y              NaN       NaN         NaN     NaN         NaN
# 4     NaN        Y              NaN       NaN         NaN     NaN         NaN
#
# ...

# %%
accidental_drug_related.isnull().sum()
# Out:
# ResidenceCity          173
# ResidenceCounty        797
# ResidenceState        1549
# DeathCity                5
# DeathCounty           1100
# Heroin                2576
# Cocaine               3584
# Fentanyl              2873
# FentanylAnalogue      4716
# Oxycodone             4498
# Oxymorphone           4997
# Ethanol               3858
# Hydrocodone           4987
# Benzodiazepine        3762
# Methadone             4631
# Amphet                4946
# Tramad                4975
# Morphine_NotHeroin    5063
# Hydromorphone         5080
# Other                 4670
# dtype: int64

# %%
accidental_drug_related.drop(['ResidenceCity','ResidenceCounty','ResidenceState','DeathCounty'], axis=1, inplace=True)

accidental_drug_related.head()
# Out:
#    DeathCity Heroin Cocaine Fentanyl FentanylAnalogue Oxycodone Oxymorphone  \
# 0        NaN    NaN     NaN        Y              NaN       NaN         NaN
# 1    NORWALK    NaN       Y      NaN              NaN       NaN         NaN
# 2    DANBURY      Y       Y      NaN              NaN       NaN         NaN
# 3  GREENWICH      Y     NaN        Y              NaN       NaN         NaN
# 4  GREENWICH    NaN     NaN        Y              NaN       NaN         NaN
#
#   Ethanol Hydrocodone Benzodiazepine Methadone Amphet Tramad  \
# 0     NaN           Y              Y       NaN    NaN    NaN
# 1     NaN         NaN            NaN       NaN    NaN    NaN
# 2     NaN         NaN            NaN       NaN    NaN    NaN
# 3     NaN         NaN            NaN       NaN    NaN    NaN
# 4     NaN         NaN            NaN       NaN    NaN    NaN
#
#   Morphine_NotHeroin Hydromorphone Other
# 0                NaN           NaN   NaN
# 1                NaN           NaN   NaN
# ...

# %%
accidental_drug_related.shape

accidental_drug_related.dropna(subset=['DeathCity'], how='any').shape

accidental_drug_related.head(10)
# Out:
#        DeathCity Heroin Cocaine Fentanyl FentanylAnalogue Oxycodone  \
# 0            NaN    NaN     NaN        Y              NaN       NaN
# 1        NORWALK    NaN       Y      NaN              NaN       NaN
# 2        DANBURY      Y       Y      NaN              NaN       NaN
# 3      GREENWICH      Y     NaN        Y              NaN       NaN
# 4      GREENWICH    NaN     NaN        Y              NaN       NaN
# 5        BRISTOL      Y     NaN      NaN              NaN       NaN
# 6  WEST HARTFORD      Y     NaN      NaN              NaN       NaN
# 7      NEW HAVEN    NaN       Y      NaN              NaN       NaN
# 8  EAST HARTFORD      Y     NaN      NaN              NaN       NaN
# 9      MONTVILLE    NaN     NaN      NaN              NaN         Y
#
#   Oxymorphone Ethanol Hydrocodone Benzodiazepine Methadone Amphet Tramad  \
# 0         NaN     NaN           Y              Y       NaN    NaN    NaN
# ...

# %%
#accidental_drug_related Heroin
adr_heroin = accidental_drug_related[accidental_drug_related.Heroin=='Y']

adr_heroin_count = adr_heroin.groupby('DeathCity').Heroin.count()
adr_heroin_impact = adr_heroin_count.nlargest(20)

#create a bar chart showing the information 
plt.xdata = adr_heroin_impact.plot.bar(legend=False)
plt.xlabel('City')
plt.ylabel('Number of Deaths')
plt.title('Number of Deaths by Heroin')

plt.show()

# %%
#accidental_drug_related Heroin
adr_heroin = accidental_drug_related[accidental_drug_related.Heroin=='Y']

adr_heroin_count = adr_heroin.groupby('DeathCity').Heroin.count()
adr_heroin_impact = adr_heroin_count.nlargest(20)

adr_heroin_count_df = pd.DataFrame(adr_heroin_impact)
adr_heroin_count_df.head(5)
# Out:
#              Heroin
# DeathCity
# HARTFORD        280
# WATERBURY       204
# NEW HAVEN       183
# BRIDGEPORT      178
# NEW BRITAIN      96

# %%
#accidental_drug_related Cocaine 
adr_cocaine = accidental_drug_related[accidental_drug_related.Cocaine=='Y']

adr_cocaine_count = adr_cocaine.groupby('DeathCity').Cocaine.count()
adr_cocaine_impact = adr_cocaine_count.nlargest(20)

#create a bar chart showing the information 
plt.xdata = adr_cocaine_impact.plot.bar(legend=False)
plt.xlabel('City')
plt.ylabel('Number of Deaths')
plt.title('Number of Deaths by Cocaine')

plt.show()

# %%
#accidental_drug_related Cocaine 
adr_cocaine = accidental_drug_related[accidental_drug_related.Cocaine=='Y']

adr_cocaine_count = adr_cocaine.groupby('DeathCity').Cocaine.count()
adr_cocaine_impact = adr_cocaine_count.nlargest(20)

adr_cocaine_count_df = pd.DataFrame(adr_cocaine_impact)
adr_cocaine_count_df.head(5)
# Out:
#              Cocaine
# DeathCity
# HARTFORD         216
# WATERBURY        139
# BRIDGEPORT       128
# NEW HAVEN        118
# NEW BRITAIN       59

# %%
heroin = [280,204,183,178,96]
cocaine = [216,139,118,128,59]
index = ['HARTFORD','WATERBURY','NEW HAVEN','BRIDGEPORT','NEW BRITAIN']
df = pd.DataFrame({'Heroin': heroin,
                'Cocaine': cocaine}, index=index)
ax = df.plot.bar(rot=0)

# %%
#accidental_drug_related Fentanyl 
adr_fentanyl = accidental_drug_related[accidental_drug_related.Fentanyl=='Y']

adr_fentanyl_count = adr_fentanyl.groupby('DeathCity').Fentanyl.count()
adr_fentanyl_impact = adr_fentanyl_count.nlargest(20)

#create a bar chart showing the information 
plt.xdata = adr_fentanyl_impact.plot.bar(legend=False)
plt.xlabel('City')
plt.ylabel('Number of Deaths')
plt.title('Number of Deaths by Fentanyl')

plt.show()

# %%
#accidental_drug_related Fentanyl 
adr_fentanyl = accidental_drug_related[accidental_drug_related.Fentanyl=='Y']

adr_fentanyl_count = adr_fentanyl.groupby('DeathCity').Fentanyl.count()
adr_fentanyl_impact = adr_fentanyl_count.nlargest(20)

adr_fentanyl_count_df = pd.DataFrame(adr_fentanyl_impact)
adr_fentanyl_count_df.head()
# Out:
#              Fentanyl
# DeathCity
# HARTFORD          289
# BRIDGEPORT        167
# WATERBURY         153
# NEW HAVEN         121
# NEW BRITAIN       107

# %%
#accidental_drug_related for FentanylAnalogue 
adr_fentanylAnalogue = accidental_drug_related[accidental_drug_related.FentanylAnalogue=='Y']

adr_fentanylAnalogue_count = adr_fentanylAnalogue.groupby('DeathCity').FentanylAnalogue.count()
adr_fentanylAnalogue_impact = adr_fentanylAnalogue_count.nlargest(20)

#create a bar chart showing the information 
plt.xdata = adr_fentanylAnalogue_impact.plot.bar(legend=False)
plt.xlabel('City')
plt.ylabel('Number of Deaths')
plt.title('Number of Deaths by FentanylAnalogue')

plt.show()

# %%
#accidental_drug_related for FentanylAnalogue 
adr_fentanylAnalogue = accidental_drug_related[accidental_drug_related.FentanylAnalogue=='Y']

adr_fentanylAnalogue_count = adr_fentanylAnalogue.groupby('DeathCity').FentanylAnalogue.count()
adr_fentanylAnalogue_impact = adr_fentanylAnalogue_count.nlargest(20)

adr_fentanylAnalogue_count_df = pd.DataFrame(adr_fentanylAnalogue_impact)
adr_fentanylAnalogue_count_df.head()
# Out:
#              FentanylAnalogue
# DeathCity
# WATERBURY                  40
# HARTFORD                   39
# NEW HAVEN                  25
# BRIDGEPORT                 22
# NEW BRITAIN                20

# %%
#accidental_drug_related Oxycodone 
adr_oxycodone = accidental_drug_related[accidental_drug_related.Oxycodone=='Y']

adr_oxycodone_count = adr_oxycodone.groupby('DeathCity').Oxycodone.count()
adr_oxycodone_impact = adr_oxycodone_count.nlargest(20)

#create a bar chart showing the information 
plt.xdata = adr_oxycodone_impact.plot.bar(legend=False)
plt.xlabel('City')
plt.ylabel('Number of Deaths')
plt.title('Number of Deaths by Oxycodone')

plt.show()

# %%
#accidental_drug_related Oxycodone 
adr_oxycodone = accidental_drug_related[accidental_drug_related.Oxycodone=='Y']

adr_oxycodone_count = adr_oxycodone.groupby('DeathCity').Oxycodone.count()
adr_oxycodone_impact = adr_oxycodone_count.nlargest(20)

adr_oxycodone_count_df = pd.DataFrame(adr_oxycodone_impact)
adr_oxycodone_count_df.head()
# Out:
#              Oxycodone
# DeathCity
# NEW HAVEN           39
# HARTFORD            35
# NEW BRITAIN         33
# WATERBURY           31
# BRIDGEPORT          29

# %%
#accidental_drug_related Oxymorphone 
adr_oxymorphone = accidental_drug_related[accidental_drug_related.Oxymorphone=='Y']

adr_oxymorphone_count = adr_oxymorphone.groupby('DeathCity').Oxymorphone.count()
adr_oxymorphone_impact = adr_oxymorphone_count.nlargest(20)

#create a bar chart showing the information 
plt.xdata = adr_oxymorphone_impact.plot.bar(legend=False)
plt.xlabel('City')
plt.ylabel('Number of Deaths')
plt.title('Number of Deaths by Oxymorphone')

plt.show()

# %%
#accidental_drug_related Oxymorphone 
adr_oxymorphone = accidental_drug_related[accidental_drug_related.Oxymorphone=='Y']

adr_oxymorphone_count = adr_oxymorphone.groupby('DeathCity').Oxymorphone.count()
adr_oxymorphone_impact = adr_oxymorphone_count.nlargest(20)

adr_oxymorphone_count_df = pd.DataFrame(adr_oxymorphone_impact)
adr_oxymorphone_count_df.head()
# Out:
#              Oxymorphone
# DeathCity
# BRIDGEPORT             6
# MERIDEN                5
# HARTFORD               4
# NEW BRITAIN            4
# STAMFORD               4

# %%
#accidental_drug_related Ethanol 
adr_ethanol = accidental_drug_related[accidental_drug_related.Ethanol=='Y']

adr_ethanol_count = adr_ethanol.groupby('DeathCity').Ethanol.count()
adr_ethanol_impact = adr_ethanol_count.nlargest(20)

#create a bar chart showing the information 
plt.xdata = adr_ethanol_impact.plot.bar(legend=False)
plt.xlabel('City')
plt.ylabel('Number of Deaths')
plt.title('Number of Deaths by Ethanol')

plt.show()

# %%
#accidental_drug_related Hydrocodone 
adr_hydrocodone = accidental_drug_related[accidental_drug_related.Hydrocodone=='Y']

adr_hydrocodone_count = adr_hydrocodone.groupby('DeathCity').Hydrocodone.count()
adr_hydrocodone_impact = adr_hydrocodone_count.nlargest(20)

#create a bar chart showing the information 
plt.xdata = adr_hydrocodone_impact.plot.bar(legend=False)
plt.xlabel('City')
plt.ylabel('Number of Deaths')
plt.title('Number of Deaths by Hydrocodone')

plt.show()

# %%
#accidental_drug_related Benzodiazepine 
adr_benzodiazepine = accidental_drug_related[accidental_drug_related.Benzodiazepine=='Y']

adr_benzodiazepine_count = adr_benzodiazepine.groupby('DeathCity').Benzodiazepine.count()
adr_benzodiazepine_impact = adr_benzodiazepine_count.nlargest(20)

#create a bar chart showing the information 
plt.xdata = adr_benzodiazepine_impact.plot.bar(legend=False)
plt.xlabel('City')
plt.ylabel('Number of Deaths')
plt.title('Number of Deaths by Benzodiazepine')

plt.show()

# %%
#accidental_drug_related Methadone 
adr_methadone = accidental_drug_related[accidental_drug_related.Methadone=='Y']

adr_methadone_count = adr_methadone.groupby('DeathCity').Methadone.count()
adr_methadone_impact = adr_methadone_count.nlargest(20)

#create a bar chart showing the information 
plt.xdata = adr_methadone_impact.plot.bar(legend=False)
plt.xlabel('City')
plt.ylabel('Number of Deaths')
plt.title('Number of Deaths by Methadone')

plt.show()

# %%
#accidental_drug_related Amphet 
adr_amphet = accidental_drug_related[accidental_drug_related.Amphet=='Y']

adr_amphet_count = adr_amphet.groupby('DeathCity').Amphet.count()
adr_amphet_impact = adr_amphet_count.nlargest(20)

#create a bar chart showing the information 
plt.xdata = adr_amphet_impact.plot.bar(legend=False)
plt.xlabel('City')
plt.ylabel('Number of Deaths')
plt.title('Number of Deaths by Amphet')

plt.show()

# %%
#accidental_drug_related Tramad 
adr_tramad = accidental_drug_related[accidental_drug_related.Tramad=='Y']

adr_tramad_count = adr_tramad.groupby('DeathCity').Tramad.count()
adr_tramad_impact = adr_tramad_count.nlargest(20)

#create a bar chart showing the information 
plt.xdata = adr_tramad_impact.plot.bar(legend=False)
plt.xlabel('City')
plt.ylabel('Number of Deaths')
plt.title('Number of Deaths by Tramad')

plt.show()

# %%
#accidental_drug_related Morphine_NotHeroin 
adr_morphine_notheroin = accidental_drug_related[accidental_drug_related.Morphine_NotHeroin=='Y']

adr_morphine_notheroin_count = adr_morphine_notheroin.groupby('DeathCity').Morphine_NotHeroin.count()
adr_morphine_notheroin_impact = adr_morphine_notheroin_count.nlargest(20)

#create a bar chart showing the information 
plt.xdata = adr_morphine_notheroin_impact.plot.bar(legend=False)
plt.xlabel('City')
plt.ylabel('Number of Deaths')
plt.title('Number of Deaths by Morphine_NotHeroin')

plt.show()

# %%
#accidental_drug_related Hydromorphone
adr_hydromorphone = accidental_drug_related[accidental_drug_related.Hydromorphone=='Y']

adr_hydromorphone_count = adr_hydromorphone.groupby('DeathCity').Hydromorphone.count()
adr_hydromorphone_impact = adr_hydromorphone_count.nlargest(20)

#create a bar chart showing the information 
plt.xdata = adr_hydromorphone_impact.plot.bar(legend=False)
plt.xlabel('City')
plt.ylabel('Number of Deaths')
plt.title('Number of Deaths by Hydromorphone')

plt.show()
